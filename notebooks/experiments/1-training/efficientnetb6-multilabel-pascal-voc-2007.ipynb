# %% [markdown]
# # Multi-label Pascal VOC 2007 CAM Assisted Training

# %% [markdown]
# **References**
#
# - Zhou, Bolei, Aditya Khosla, Agata Lapedriza, Aude Oliva, and Antonio Torralba. “Learning deep features for discriminative localization.” IEEE conference on computer vision and pattern recognition (CVPR), pp. 2921-2929. 2016. [1512.04150](https://arxiv.org/pdf/1512.04150.pdf)

# %%
#@title

! pip -qq install tensorflow-addons

from google.colab import drive
drive.mount('/content/drive')
# Out:
#      |████████████████████████████████| 686kB 9.0MB/s
# Mounted at /content/drive

# %%
import tensorflow as tf

class Config:
  class data:
    size = (528, 528)
    shape = (*size, 3)
    batch_size = 32
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 120391
    shuffle = True

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    last_spatial_layer = 'en6'
    first_dense_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB6
  
  class training:
    epochs = 80
    learning_rate = .002
    lr_first_decay_steps = 50
    
    fine_tune_lr = .00001
    fine_tune_epochs = 45
    fine_tune_layers = .3
    freeze_batch_norm = False

    fine_tune_early_stopping_patience = 20

  class experiment:
    seed = 218402
    override = True
    logs                 = '/content/drive/MyDrive/unicamp_logs/pascal/e6-ce/'
    fine_tune_logs       = '/content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/'

    training_weights     = '/content/drive/MyDrive/unicamp_logs/pascal/e6-ce/weights.h5'
    fine_tune_weights    = '/content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights.h5'

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Augmentation Policy

# %%
def default_policy_fn(image):
  image = tf.image.resize_with_crop_or_pad(image, *Config.data.size)
  # mask = tf.image.resize_with_crop_or_pad(mask, *Config.data.size)

  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.resize_with_crop_or_pad(image, *Config.data.size)
  # image = tf.image.stateless_random_crop(image, [*Config.data.size, 3], seed=seeds[:, 0])
  # mask = tf.image.stateless_random_crop(mask, [*Config.data.size, 1], seed=seeds[:, 0])

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  # mask = tf.image.stateless_random_flip_left_right(mask, seed=seeds[:, 0])
  
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  # mask = tf.image.stateless_random_flip_up_down(mask, seed=seeds[:, 1])

  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %% [markdown]
# ### Preparing and Performance Settings

# %%
# %%bash
#
# if ! [ -d "/root/tensorflow_datasets/voc/2007" ]; then
#   unzip -nq "/content/drive/MyDrive/unicamp_datasets/pascal-voc-2007.zip" -d /
# else
#   echo "Data found at voc/2007 - skipping"
# fi

# %%
(train_dataset, val_dataset, test_dataset), info = tfds.load(
  'voc/2007',
  split=('train', 'validation', 'test'),
  with_info=True,
  shuffle_files=False
)

# %%
CLASSES = np.asarray(info.features['objects']['label']._int2str)
int2str = info.features['objects']['label'].int2str

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['objects']['label']

  image = tf.cast(image, tf.float32)
  
  image, _ = adjust_resolution(image)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  return image, labels_to_one_hot(labels)


def adjust_resolution(image):
  es = tf.constant(Config.data.size, tf.float32)
  xs = tf.cast(tf.shape(image)[:2], tf.float32)

  ratio = tf.reduce_min(es / xs)
  xsn = tf.cast(tf.math.ceil(ratio * xs), tf.int32)

  image = tf.image.resize(image, xsn, preserve_aspect_ratio=True, method='nearest')

  return image, ratio


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(val_dataset, Config.data.batch_size)
test = prepare(test_dataset, Config.data.batch_size)

# %% [markdown]
# ### Examples in The Dataset

# %%
def talk_about(dataset, batches, tag):
  print(tag)
  print(f'  {batches}')
  print(f'  samples: {len(dataset)}')
  print(f'  steps  : {len(batches)}')
  print()


talk_about(train_dataset, train, 'Training')
talk_about(val_dataset, valid, 'Validation')
# Out:
# Training
#   <PrefetchDataset shapes: ((32, 528, 528, 3), (32, 20)), types: (tf.float32, tf.float32)>
#   samples: 2501
#   steps  : 78
#
# Validation
#   <PrefetchDataset shapes: ((32, 528, 528, 3), (32, 20)), types: (tf.float32, tf.float32)>
#   samples: 2510
#   steps  : 78

# %%
#@title

for images, labels in train.take(1):
  gt = ['\n'.join(CLASSES[l].astype(str))
        for l in labels.numpy().astype(bool)]

  visualize(
    tf.cast(images[:16], tf.uint8),
    gt,
    rows=2,
    figsize=(16, 6)
  )

# %% [markdown]
# ## Network

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB6
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 2s 0us/step

# %%
from tensorflow.keras.layers import Conv2D, Dense, Dropout, GlobalAveragePooling2D

class DenseKur(Dense):
  """Dense with Softmax Weights.
  """
  def call(self, inputs):
    kernel = self.kernel
    ag = kernel  # tf.abs(kernel)
    ag = ag - tf.reduce_max(ag, axis=-1, keepdims=True)
    ag = tf.nn.softmax(ag)

    outputs = inputs @ (ag*kernel)

    if self.use_bias:
      outputs = tf.nn.bias_add(outputs, self.bias)

    if self.activation is not None:
      outputs = self.activation(outputs)

    return outputs

# %%
from tensorflow.keras.layers import Dropout, Dense, GlobalAveragePooling2D


def build_specific_classifier(
    backbone,
    classes,
    dropout_rate=0.5,
    name=None,
    gpl='avg_pool',
):

  x = tf.keras.Input(shape=Config.data.shape, name='input_images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name='avg_pool')(y)
  # y = DenseKur(classes, name='predictions')(y)
  y = Dense(classes, name='predictions')(y)

  return tf.keras.Model(
    x,
    y,
    name=name
  )

backbone.trainable = False

nn = build_specific_classifier(
  backbone,
  len(CLASSES),
  Config.model.feature_layers,
  name=f'{Config.model.backbone.__name__}_voc_20')

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Loss, Metrics and Model Compilation

# %%
#@title

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)


class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

# %%
model_metrics = [
  AUC(from_logits=True),
  BinaryAccuracy(from_logits=True),
  F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
  Precision(from_logits=True),
  Recall(from_logits=True),
  # TruePositives(from_logits=True),
  # FalsePositives(from_logits=True),
  # TrueNegatives(from_logits=True),
  # FalseNegatives(from_logits=True),
]

# %%
nn.compile(
    optimizer=tf.optimizers.SGD(learning_rate=Config.training.learning_rate, momentum=0.9, nesterov=True),
    loss=tf.losses.BinaryCrossentropy(from_logits=True),
    metrics=model_metrics)

# %%
nn.evaluate(tf.random.normal((2, *Config.data.shape)));
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - auc: 0.0000e+00 - binary_accuracy: 0.0000e+00 - f1_score: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00

# %% [markdown]
# ### Top Classifier Training

# %%
cs = [
    callbacks.TerminateOnNaN(),
    callbacks.ModelCheckpoint(Config.experiment.training_weights,
                              save_best_only=True,
                              save_weights_only=True,
                              verbose=1),
    callbacks.TensorBoard(
      Config.experiment.logs,
      write_graph=True,
      profile_batch=0)
]

# %%
try:
  if os.path.exists(Config.experiment.logs):
    if not Config.experiment.override:
      raise ValueError(f'A training was found in {Config.experiment.logs}. '
                       f'Either move it or set experiment.override to True.')

    print(f'Overriding previous training at {Config.experiment.logs}.')
    shutil.rmtree(Config.experiment.logs)

  nn.fit(
    train,
    initial_epoch=50,
    validation_data=valid,
    epochs=Config.training.epochs,
    callbacks=cs
  );

except KeyboardInterrupt: print('\ninterrupted')
else: print('\ndone')
# Out:
# Overriding previous training at /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/.
# Epoch 51/80
# 78/78 [==============================] - 319s 3s/step - loss: 0.5907 - auc: 0.6551 - binary_accuracy: 0.8949 - f1_score: 0.2230 - precision: 0.3034 - recall: 0.2373 - val_loss: 0.5660 - val_auc: 0.7196 - val_binary_accuracy: 0.9168 - val_f1_score: 0.4551 - val_precision: 0.4334 - val_recall: 0.2327
#
# Epoch 00051: val_loss improved from inf to 0.56601, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 52/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.4516 - auc: 0.7228 - binary_accuracy: 0.9278 - f1_score: 0.3222 - precision: 0.6507 - recall: 0.2166 - val_loss: 0.4684 - val_auc: 0.7895 - val_binary_accuracy: 0.9348 - val_f1_score: 0.5174 - val_precision: 0.8550 - val_recall: 0.1932
#
# Epoch 00052: val_loss improved from 0.56601 to 0.46840, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 53/80
# 78/78 [==============================] - 270s 3s/step - loss: 0.3729 - auc: 0.7736 - binary_accuracy: 0.9327 - f1_score: 0.3743 - precision: 0.8072 - recall: 0.2120 - val_loss: 0.3956 - val_auc: 0.8505 - val_binary_accuracy: 0.9365 - val_f1_score: 0.5402 - val_precision: 0.9414 - val_recall: 0.1947
#
# Epoch 00053: val_loss improved from 0.46840 to 0.39562, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 54/80
# 78/78 [==============================] - 270s 3s/step - loss: 0.3199 - auc: 0.8207 - binary_accuracy: 0.9350 - f1_score: 0.3847 - precision: 0.8689 - recall: 0.2247 - val_loss: 0.3422 - val_auc: 0.8914 - val_binary_accuracy: 0.9377 - val_f1_score: 0.5611 - val_precision: 0.9496 - val_recall: 0.2089
#
# Epoch 00054: val_loss improved from 0.39562 to 0.34217, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 55/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.2824 - auc: 0.8504 - binary_accuracy: 0.9372 - f1_score: 0.4015 - precision: 0.8806 - recall: 0.2519 - val_loss: 0.3037 - val_auc: 0.9167 - val_binary_accuracy: 0.9400 - val_f1_score: 0.5825 - val_precision: 0.9574 - val_recall: 0.2378
#
# Epoch 00055: val_loss improved from 0.34217 to 0.30370, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 56/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.2563 - auc: 0.8785 - binary_accuracy: 0.9394 - f1_score: 0.4278 - precision: 0.9059 - recall: 0.2736 - val_loss: 0.2738 - val_auc: 0.9330 - val_binary_accuracy: 0.9432 - val_f1_score: 0.6073 - val_precision: 0.9594 - val_recall: 0.2801
#
# Epoch 00056: val_loss improved from 0.30370 to 0.27384, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 57/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.2364 - auc: 0.8982 - binary_accuracy: 0.9412 - f1_score: 0.4535 - precision: 0.9112 - recall: 0.2972 - val_loss: 0.2507 - val_auc: 0.9445 - val_binary_accuracy: 0.9467 - val_f1_score: 0.6235 - val_precision: 0.9593 - val_recall: 0.3281
#
# Epoch 00057: val_loss improved from 0.27384 to 0.25073, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 58/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.2207 - auc: 0.9057 - binary_accuracy: 0.9437 - f1_score: 0.4758 - precision: 0.9097 - recall: 0.3315 - val_loss: 0.2328 - val_auc: 0.9519 - val_binary_accuracy: 0.9497 - val_f1_score: 0.6393 - val_precision: 0.9584 - val_recall: 0.3686
#
# Epoch 00058: val_loss improved from 0.25073 to 0.23278, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 59/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.2077 - auc: 0.9220 - binary_accuracy: 0.9456 - f1_score: 0.4955 - precision: 0.9121 - recall: 0.3571 - val_loss: 0.2189 - val_auc: 0.9568 - val_binary_accuracy: 0.9527 - val_f1_score: 0.6546 - val_precision: 0.9566 - val_recall: 0.4093
#
# Epoch 00059: val_loss improved from 0.23278 to 0.21890, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 60/80
# 78/78 [==============================] - 270s 3s/step - loss: 0.1981 - auc: 0.9278 - binary_accuracy: 0.9474 - f1_score: 0.5113 - precision: 0.9192 - recall: 0.3775 - val_loss: 0.2075 - val_auc: 0.9606 - val_binary_accuracy: 0.9550 - val_f1_score: 0.6727 - val_precision: 0.9558 - val_recall: 0.4405
#
# Epoch 00060: val_loss improved from 0.21890 to 0.20745, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 61/80
# 78/78 [==============================] - 272s 3s/step - loss: 0.1903 - auc: 0.9314 - binary_accuracy: 0.9501 - f1_score: 0.5258 - precision: 0.9273 - recall: 0.4105 - val_loss: 0.1984 - val_auc: 0.9630 - val_binary_accuracy: 0.9566 - val_f1_score: 0.6844 - val_precision: 0.9539 - val_recall: 0.4640
#
# Epoch 00061: val_loss improved from 0.20745 to 0.19842, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 62/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.1836 - auc: 0.9366 - binary_accuracy: 0.9511 - f1_score: 0.5518 - precision: 0.9227 - recall: 0.4260 - val_loss: 0.1912 - val_auc: 0.9648 - val_binary_accuracy: 0.9578 - val_f1_score: 0.6914 - val_precision: 0.9493 - val_recall: 0.4828
#
# Epoch 00062: val_loss improved from 0.19842 to 0.19118, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 63/80
# 78/78 [==============================] - 272s 4s/step - loss: 0.1799 - auc: 0.9368 - binary_accuracy: 0.9515 - f1_score: 0.5535 - precision: 0.9197 - recall: 0.4341 - val_loss: 0.1855 - val_auc: 0.9663 - val_binary_accuracy: 0.9586 - val_f1_score: 0.6956 - val_precision: 0.9467 - val_recall: 0.4950
#
# Epoch 00063: val_loss improved from 0.19118 to 0.18554, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 64/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.1755 - auc: 0.9392 - binary_accuracy: 0.9527 - f1_score: 0.5698 - precision: 0.9190 - recall: 0.4502 - val_loss: 0.1810 - val_auc: 0.9673 - val_binary_accuracy: 0.9596 - val_f1_score: 0.6997 - val_precision: 0.9467 - val_recall: 0.5081
#
# Epoch 00064: val_loss improved from 0.18554 to 0.18098, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 65/80
# 78/78 [==============================] - 271s 3s/step - loss: 0.1731 - auc: 0.9421 - binary_accuracy: 0.9521 - f1_score: 0.5680 - precision: 0.9187 - recall: 0.4426 - val_loss: 0.1775 - val_auc: 0.9682 - val_binary_accuracy: 0.9601 - val_f1_score: 0.7029 - val_precision: 0.9456 - val_recall: 0.5159
#
# Epoch 00065: val_loss improved from 0.18098 to 0.17751, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 66/80
# 78/78 [==============================] - 272s 3s/step - loss: 0.1700 - auc: 0.9423 - binary_accuracy: 0.9541 - f1_score: 0.5847 - precision: 0.9187 - recall: 0.4706 - val_loss: 0.1747 - val_auc: 0.9687 - val_binary_accuracy: 0.9605 - val_f1_score: 0.7058 - val_precision: 0.9453 - val_recall: 0.5213
#
# Epoch 00066: val_loss improved from 0.17751 to 0.17473, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 67/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1674 - auc: 0.9432 - binary_accuracy: 0.9543 - f1_score: 0.5735 - precision: 0.9198 - recall: 0.4718 - val_loss: 0.1726 - val_auc: 0.9692 - val_binary_accuracy: 0.9609 - val_f1_score: 0.7090 - val_precision: 0.9454 - val_recall: 0.5267
#
# Epoch 00067: val_loss improved from 0.17473 to 0.17257, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 68/80
# 78/78 [==============================] - 272s 4s/step - loss: 0.1663 - auc: 0.9463 - binary_accuracy: 0.9540 - f1_score: 0.5719 - precision: 0.9193 - recall: 0.4686 - val_loss: 0.1709 - val_auc: 0.9695 - val_binary_accuracy: 0.9611 - val_f1_score: 0.7096 - val_precision: 0.9444 - val_recall: 0.5298
#
# Epoch 00068: val_loss improved from 0.17257 to 0.17086, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 69/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1645 - auc: 0.9457 - binary_accuracy: 0.9545 - f1_score: 0.5851 - precision: 0.9226 - recall: 0.4729 - val_loss: 0.1694 - val_auc: 0.9697 - val_binary_accuracy: 0.9612 - val_f1_score: 0.7115 - val_precision: 0.9425 - val_recall: 0.5331
#
# Epoch 00069: val_loss improved from 0.17086 to 0.16943, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 70/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1639 - auc: 0.9454 - binary_accuracy: 0.9547 - f1_score: 0.5835 - precision: 0.9221 - recall: 0.4757 - val_loss: 0.1682 - val_auc: 0.9699 - val_binary_accuracy: 0.9614 - val_f1_score: 0.7120 - val_precision: 0.9424 - val_recall: 0.5357
#
# Epoch 00070: val_loss improved from 0.16943 to 0.16818, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 71/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1590 - auc: 0.9459 - binary_accuracy: 0.9558 - f1_score: 0.5800 - precision: 0.9182 - recall: 0.4930 - val_loss: 0.1577 - val_auc: 0.9718 - val_binary_accuracy: 0.9629 - val_f1_score: 0.7186 - val_precision: 0.9374 - val_recall: 0.5602
#
# Epoch 00071: val_loss improved from 0.16818 to 0.15771, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 72/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1526 - auc: 0.9511 - binary_accuracy: 0.9561 - f1_score: 0.6010 - precision: 0.9136 - recall: 0.5014 - val_loss: 0.1491 - val_auc: 0.9735 - val_binary_accuracy: 0.9647 - val_f1_score: 0.7218 - val_precision: 0.9361 - val_recall: 0.5852
#
# Epoch 00072: val_loss improved from 0.15771 to 0.14905, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 73/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1446 - auc: 0.9543 - binary_accuracy: 0.9592 - f1_score: 0.6169 - precision: 0.9232 - recall: 0.5365 - val_loss: 0.1417 - val_auc: 0.9746 - val_binary_accuracy: 0.9654 - val_f1_score: 0.7287 - val_precision: 0.9310 - val_recall: 0.5987
#
# Epoch 00073: val_loss improved from 0.14905 to 0.14175, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 74/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1395 - auc: 0.9573 - binary_accuracy: 0.9593 - f1_score: 0.6215 - precision: 0.9079 - recall: 0.5484 - val_loss: 0.1356 - val_auc: 0.9754 - val_binary_accuracy: 0.9662 - val_f1_score: 0.7304 - val_precision: 0.9278 - val_recall: 0.6128
#
# Epoch 00074: val_loss improved from 0.14175 to 0.13556, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 75/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1367 - auc: 0.9558 - binary_accuracy: 0.9596 - f1_score: 0.6319 - precision: 0.9066 - recall: 0.5542 - val_loss: 0.1304 - val_auc: 0.9762 - val_binary_accuracy: 0.9671 - val_f1_score: 0.7361 - val_precision: 0.9273 - val_recall: 0.6250
#
# Epoch 00075: val_loss improved from 0.13556 to 0.13040, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 76/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1316 - auc: 0.9605 - binary_accuracy: 0.9610 - f1_score: 0.6327 - precision: 0.9061 - recall: 0.5731 - val_loss: 0.1261 - val_auc: 0.9769 - val_binary_accuracy: 0.9677 - val_f1_score: 0.7388 - val_precision: 0.9250 - val_recall: 0.6361
#
# Epoch 00076: val_loss improved from 0.13040 to 0.12610, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 77/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1301 - auc: 0.9589 - binary_accuracy: 0.9606 - f1_score: 0.6334 - precision: 0.9003 - recall: 0.5725 - val_loss: 0.1226 - val_auc: 0.9774 - val_binary_accuracy: 0.9684 - val_f1_score: 0.7446 - val_precision: 0.9250 - val_recall: 0.6453
#
# Epoch 00077: val_loss improved from 0.12610 to 0.12262, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 78/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1276 - auc: 0.9589 - binary_accuracy: 0.9618 - f1_score: 0.6436 - precision: 0.9090 - recall: 0.5830 - val_loss: 0.1197 - val_auc: 0.9777 - val_binary_accuracy: 0.9686 - val_f1_score: 0.7451 - val_precision: 0.9209 - val_recall: 0.6518
#
# Epoch 00078: val_loss improved from 0.12262 to 0.11966, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 79/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1246 - auc: 0.9619 - binary_accuracy: 0.9626 - f1_score: 0.6494 - precision: 0.9044 - recall: 0.5972 - val_loss: 0.1171 - val_auc: 0.9781 - val_binary_accuracy: 0.9688 - val_f1_score: 0.7464 - val_precision: 0.9182 - val_recall: 0.6570
#
# Epoch 00079: val_loss improved from 0.11966 to 0.11712, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
# Epoch 80/80
# 78/78 [==============================] - 273s 4s/step - loss: 0.1222 - auc: 0.9634 - binary_accuracy: 0.9627 - f1_score: 0.6507 - precision: 0.8924 - recall: 0.6085 - val_loss: 0.1150 - val_auc: 0.9784 - val_binary_accuracy: 0.9692 - val_f1_score: 0.7478 - val_precision: 0.9193 - val_recall: 0.6611
#
# Epoch 00080: val_loss improved from 0.11712 to 0.11504, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-sw-ce/weights.h5
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
nn.load_weights(Config.experiment.training_weights, by_name=True)

# %%
trained_epochs = 80  # 114  # len(nn.history.history['loss'])

# %%
if Config.training.fine_tune_epochs:
  backbone.trainable = True

  frozen_layer_ix = int((1-Config.training.fine_tune_layers) * len(backbone.layers))
  for ix, l in enumerate(backbone.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not Config.training.freeze_batch_norm))

  nn.compile(
    optimizer=tf.optimizers.SGD(learning_rate=Config.training.fine_tune_lr, momentum=0.9, nesterov=True),
    loss=tf.losses.BinaryCrossentropy(from_logits=True),
    metrics=model_metrics)

# %%
if Config.training.fine_tune_epochs:
  print(f'Fine tuning params:')
  print(f'  epochs:          {Config.training.fine_tune_epochs}')
  print(f'  learning rate:   {Config.training.fine_tune_lr}')
  print(f'  layers unfrozen: {frozen_layer_ix} to {len(backbone.layers)}')

  try:
    history = nn.fit(
      train,
      validation_data=valid,
      epochs=trained_epochs + Config.training.fine_tune_epochs,
      callbacks=[
        callbacks.TerminateOnNaN(),
        callbacks.ModelCheckpoint(Config.experiment.fine_tune_weights.rstrip('.h5') + '-e114.h5',
                                  save_best_only=True,
                                  save_weights_only=True,
                                  verbose=1),
        callbacks.ReduceLROnPlateau(min_lr=1e-5),
        callbacks.EarlyStopping(patience=Config.training.fine_tune_early_stopping_patience, verbose=1),
        callbacks.TensorBoard(
          Config.experiment.fine_tune_logs,
          write_graph=False)
      ],
      initial_epoch=trained_epochs,
    );

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')
# Out:
# Fine tuning params:
#   epochs:          45
#   learning rate:   1e-05
#   layers unfrozen: 466 to 666
# Epoch 81/125
# 78/78 [==============================] - 371s 4s/step - loss: 0.3242 - auc: 0.9473 - binary_accuracy: 0.8688 - f1_score: 0.6978 - precision: 0.3708 - recall: 0.8776 - val_loss: 0.0792 - val_auc: 0.9773 - val_binary_accuracy: 0.9754 - val_f1_score: 0.7637 - val_precision: 0.8993 - val_recall: 0.7692
#
# Epoch 00081: val_loss improved from inf to 0.07920, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 82/125
# 78/78 [==============================] - 325s 4s/step - loss: 0.1169 - auc: 0.9657 - binary_accuracy: 0.9598 - f1_score: 0.6922 - precision: 0.7475 - recall: 0.7405 - val_loss: 0.0829 - val_auc: 0.9756 - val_binary_accuracy: 0.9746 - val_f1_score: 0.7521 - val_precision: 0.9038 - val_recall: 0.7537
#
# Epoch 00082: val_loss did not improve from 0.07920
# Epoch 83/125
# 78/78 [==============================] - 327s 4s/step - loss: 0.0955 - auc: 0.9743 - binary_accuracy: 0.9663 - f1_score: 0.6786 - precision: 0.8229 - recall: 0.7248 - val_loss: 0.0812 - val_auc: 0.9766 - val_binary_accuracy: 0.9746 - val_f1_score: 0.7485 - val_precision: 0.9067 - val_recall: 0.7498
#
# Epoch 00083: val_loss did not improve from 0.07920
# Epoch 84/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0855 - auc: 0.9793 - binary_accuracy: 0.9691 - f1_score: 0.6907 - precision: 0.8626 - recall: 0.7196 - val_loss: 0.0780 - val_auc: 0.9780 - val_binary_accuracy: 0.9749 - val_f1_score: 0.7445 - val_precision: 0.9162 - val_recall: 0.7446
#
# Epoch 00084: val_loss improved from 0.07920 to 0.07798, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 85/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0791 - auc: 0.9820 - binary_accuracy: 0.9715 - f1_score: 0.6921 - precision: 0.8710 - recall: 0.7472 - val_loss: 0.0757 - val_auc: 0.9790 - val_binary_accuracy: 0.9752 - val_f1_score: 0.7425 - val_precision: 0.9225 - val_recall: 0.7428
#
# Epoch 00085: val_loss improved from 0.07798 to 0.07567, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 86/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0736 - auc: 0.9847 - binary_accuracy: 0.9732 - f1_score: 0.6971 - precision: 0.8761 - recall: 0.7672 - val_loss: 0.0738 - val_auc: 0.9798 - val_binary_accuracy: 0.9755 - val_f1_score: 0.7416 - val_precision: 0.9265 - val_recall: 0.7441
#
# Epoch 00086: val_loss improved from 0.07567 to 0.07380, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 87/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0690 - auc: 0.9877 - binary_accuracy: 0.9747 - f1_score: 0.7132 - precision: 0.8866 - recall: 0.7765 - val_loss: 0.0721 - val_auc: 0.9807 - val_binary_accuracy: 0.9761 - val_f1_score: 0.7412 - val_precision: 0.9290 - val_recall: 0.7495
#
# Epoch 00087: val_loss improved from 0.07380 to 0.07213, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 88/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0681 - auc: 0.9862 - binary_accuracy: 0.9755 - f1_score: 0.7032 - precision: 0.8938 - recall: 0.7784 - val_loss: 0.0705 - val_auc: 0.9812 - val_binary_accuracy: 0.9765 - val_f1_score: 0.7412 - val_precision: 0.9300 - val_recall: 0.7537
#
# Epoch 00088: val_loss improved from 0.07213 to 0.07049, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 89/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0642 - auc: 0.9886 - binary_accuracy: 0.9770 - f1_score: 0.7169 - precision: 0.8924 - recall: 0.8045 - val_loss: 0.0693 - val_auc: 0.9817 - val_binary_accuracy: 0.9768 - val_f1_score: 0.7399 - val_precision: 0.9298 - val_recall: 0.7586
#
# Epoch 00089: val_loss improved from 0.07049 to 0.06927, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 90/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0632 - auc: 0.9896 - binary_accuracy: 0.9766 - f1_score: 0.7047 - precision: 0.8850 - recall: 0.8047 - val_loss: 0.0681 - val_auc: 0.9821 - val_binary_accuracy: 0.9773 - val_f1_score: 0.7404 - val_precision: 0.9298 - val_recall: 0.7658
#
# Epoch 00090: val_loss improved from 0.06927 to 0.06810, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 91/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0602 - auc: 0.9905 - binary_accuracy: 0.9783 - f1_score: 0.7177 - precision: 0.9049 - recall: 0.8095 - val_loss: 0.0671 - val_auc: 0.9828 - val_binary_accuracy: 0.9777 - val_f1_score: 0.7418 - val_precision: 0.9325 - val_recall: 0.7692
#
# Epoch 00091: val_loss improved from 0.06810 to 0.06713, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 92/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0577 - auc: 0.9919 - binary_accuracy: 0.9788 - f1_score: 0.7140 - precision: 0.9069 - recall: 0.8140 - val_loss: 0.0662 - val_auc: 0.9832 - val_binary_accuracy: 0.9782 - val_f1_score: 0.7440 - val_precision: 0.9332 - val_recall: 0.7746
#
# Epoch 00092: val_loss improved from 0.06713 to 0.06619, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 93/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0545 - auc: 0.9930 - binary_accuracy: 0.9801 - f1_score: 0.7164 - precision: 0.9075 - recall: 0.8307 - val_loss: 0.0655 - val_auc: 0.9833 - val_binary_accuracy: 0.9785 - val_f1_score: 0.7445 - val_precision: 0.9340 - val_recall: 0.7779
#
# Epoch 00093: val_loss improved from 0.06619 to 0.06548, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 94/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0542 - auc: 0.9928 - binary_accuracy: 0.9798 - f1_score: 0.7360 - precision: 0.9064 - recall: 0.8279 - val_loss: 0.0648 - val_auc: 0.9834 - val_binary_accuracy: 0.9786 - val_f1_score: 0.7438 - val_precision: 0.9347 - val_recall: 0.7792
#
# Epoch 00094: val_loss improved from 0.06548 to 0.06478, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 95/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0547 - auc: 0.9922 - binary_accuracy: 0.9798 - f1_score: 0.7248 - precision: 0.9082 - recall: 0.8250 - val_loss: 0.0644 - val_auc: 0.9835 - val_binary_accuracy: 0.9788 - val_f1_score: 0.7448 - val_precision: 0.9357 - val_recall: 0.7805
#
# Epoch 00095: val_loss improved from 0.06478 to 0.06437, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 96/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0502 - auc: 0.9942 - binary_accuracy: 0.9820 - f1_score: 0.7200 - precision: 0.9193 - recall: 0.8448 - val_loss: 0.0638 - val_auc: 0.9836 - val_binary_accuracy: 0.9790 - val_f1_score: 0.7453 - val_precision: 0.9356 - val_recall: 0.7831
#
# Epoch 00096: val_loss improved from 0.06437 to 0.06380, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 97/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0489 - auc: 0.9937 - binary_accuracy: 0.9822 - f1_score: 0.7292 - precision: 0.9216 - recall: 0.8470 - val_loss: 0.0631 - val_auc: 0.9839 - val_binary_accuracy: 0.9793 - val_f1_score: 0.7450 - val_precision: 0.9356 - val_recall: 0.7872
#
# Epoch 00097: val_loss improved from 0.06380 to 0.06312, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 98/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0470 - auc: 0.9932 - binary_accuracy: 0.9831 - f1_score: 0.7267 - precision: 0.9225 - recall: 0.8541 - val_loss: 0.0630 - val_auc: 0.9834 - val_binary_accuracy: 0.9792 - val_f1_score: 0.7454 - val_precision: 0.9377 - val_recall: 0.7841
#
# Epoch 00098: val_loss improved from 0.06312 to 0.06301, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 99/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0461 - auc: 0.9944 - binary_accuracy: 0.9835 - f1_score: 0.7281 - precision: 0.9276 - recall: 0.8558 - val_loss: 0.0624 - val_auc: 0.9836 - val_binary_accuracy: 0.9795 - val_f1_score: 0.7476 - val_precision: 0.9366 - val_recall: 0.7890
#
# Epoch 00099: val_loss improved from 0.06301 to 0.06236, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 100/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0428 - auc: 0.9956 - binary_accuracy: 0.9850 - f1_score: 0.7395 - precision: 0.9295 - recall: 0.8744 - val_loss: 0.0624 - val_auc: 0.9836 - val_binary_accuracy: 0.9795 - val_f1_score: 0.7472 - val_precision: 0.9377 - val_recall: 0.7888
#
# Epoch 00100: val_loss did not improve from 0.06236
# Epoch 101/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0432 - auc: 0.9957 - binary_accuracy: 0.9843 - f1_score: 0.7294 - precision: 0.9253 - recall: 0.8681 - val_loss: 0.0619 - val_auc: 0.9838 - val_binary_accuracy: 0.9796 - val_f1_score: 0.7475 - val_precision: 0.9346 - val_recall: 0.7926
#
# Epoch 00101: val_loss improved from 0.06236 to 0.06190, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 102/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0430 - auc: 0.9948 - binary_accuracy: 0.9845 - f1_score: 0.7381 - precision: 0.9287 - recall: 0.8677 - val_loss: 0.0617 - val_auc: 0.9838 - val_binary_accuracy: 0.9797 - val_f1_score: 0.7464 - val_precision: 0.9382 - val_recall: 0.7908
#
# Epoch 00102: val_loss improved from 0.06190 to 0.06173, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 103/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0390 - auc: 0.9960 - binary_accuracy: 0.9862 - f1_score: 0.7366 - precision: 0.9423 - recall: 0.8773 - val_loss: 0.0614 - val_auc: 0.9837 - val_binary_accuracy: 0.9799 - val_f1_score: 0.7458 - val_precision: 0.9378 - val_recall: 0.7939
#
# Epoch 00103: val_loss improved from 0.06173 to 0.06138, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 104/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0401 - auc: 0.9963 - binary_accuracy: 0.9853 - f1_score: 0.7376 - precision: 0.9337 - recall: 0.8736 - val_loss: 0.0613 - val_auc: 0.9838 - val_binary_accuracy: 0.9800 - val_f1_score: 0.7463 - val_precision: 0.9382 - val_recall: 0.7947
#
# Epoch 00104: val_loss improved from 0.06138 to 0.06128, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 105/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0388 - auc: 0.9966 - binary_accuracy: 0.9860 - f1_score: 0.7485 - precision: 0.9358 - recall: 0.8818 - val_loss: 0.0611 - val_auc: 0.9833 - val_binary_accuracy: 0.9803 - val_f1_score: 0.7452 - val_precision: 0.9392 - val_recall: 0.7975
#
# Epoch 00105: val_loss improved from 0.06128 to 0.06112, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 106/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0366 - auc: 0.9972 - binary_accuracy: 0.9866 - f1_score: 0.7360 - precision: 0.9402 - recall: 0.8870 - val_loss: 0.0607 - val_auc: 0.9836 - val_binary_accuracy: 0.9802 - val_f1_score: 0.7459 - val_precision: 0.9357 - val_recall: 0.8001
#
# Epoch 00106: val_loss improved from 0.06112 to 0.06066, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 107/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0380 - auc: 0.9961 - binary_accuracy: 0.9862 - f1_score: 0.7355 - precision: 0.9373 - recall: 0.8842 - val_loss: 0.0603 - val_auc: 0.9839 - val_binary_accuracy: 0.9804 - val_f1_score: 0.7471 - val_precision: 0.9352 - val_recall: 0.8040
#
# Epoch 00107: val_loss improved from 0.06066 to 0.06032, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 108/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0349 - auc: 0.9969 - binary_accuracy: 0.9875 - f1_score: 0.7327 - precision: 0.9360 - recall: 0.9023 - val_loss: 0.0603 - val_auc: 0.9836 - val_binary_accuracy: 0.9804 - val_f1_score: 0.7459 - val_precision: 0.9362 - val_recall: 0.8029
#
# Epoch 00108: val_loss improved from 0.06032 to 0.06030, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 109/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0337 - auc: 0.9967 - binary_accuracy: 0.9884 - f1_score: 0.7549 - precision: 0.9498 - recall: 0.8988 - val_loss: 0.0602 - val_auc: 0.9838 - val_binary_accuracy: 0.9806 - val_f1_score: 0.7472 - val_precision: 0.9369 - val_recall: 0.8042
#
# Epoch 00109: val_loss improved from 0.06030 to 0.06017, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 110/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0313 - auc: 0.9977 - binary_accuracy: 0.9895 - f1_score: 0.7511 - precision: 0.9522 - recall: 0.9111 - val_loss: 0.0601 - val_auc: 0.9833 - val_binary_accuracy: 0.9807 - val_f1_score: 0.7457 - val_precision: 0.9378 - val_recall: 0.8045
#
# Epoch 00110: val_loss improved from 0.06017 to 0.06013, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 111/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0314 - auc: 0.9979 - binary_accuracy: 0.9887 - f1_score: 0.7423 - precision: 0.9542 - recall: 0.9001 - val_loss: 0.0603 - val_auc: 0.9833 - val_binary_accuracy: 0.9807 - val_f1_score: 0.7431 - val_precision: 0.9388 - val_recall: 0.8037
#
# Epoch 00111: val_loss did not improve from 0.06013
# Epoch 112/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0290 - auc: 0.9982 - binary_accuracy: 0.9903 - f1_score: 0.7379 - precision: 0.9559 - recall: 0.9186 - val_loss: 0.0597 - val_auc: 0.9830 - val_binary_accuracy: 0.9809 - val_f1_score: 0.7429 - val_precision: 0.9362 - val_recall: 0.8096
#
# Epoch 00112: val_loss improved from 0.06013 to 0.05971, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 113/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0300 - auc: 0.9979 - binary_accuracy: 0.9894 - f1_score: 0.7379 - precision: 0.9505 - recall: 0.9116 - val_loss: 0.0595 - val_auc: 0.9832 - val_binary_accuracy: 0.9811 - val_f1_score: 0.7434 - val_precision: 0.9371 - val_recall: 0.8112
#
# Epoch 00113: val_loss improved from 0.05971 to 0.05947, saving model to /content/drive/MyDrive/unicamp_logs/pascal/e6-ce-fine-tune/weights-e114.h5
# Epoch 114/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0289 - auc: 0.9979 - binary_accuracy: 0.9901 - f1_score: 0.7573 - precision: 0.9580 - recall: 0.9143 - val_loss: 0.0596 - val_auc: 0.9830 - val_binary_accuracy: 0.9809 - val_f1_score: 0.7426 - val_precision: 0.9351 - val_recall: 0.8104
#
# Epoch 00114: val_loss did not improve from 0.05947
# Epoch 115/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0266 - auc: 0.9987 - binary_accuracy: 0.9906 - f1_score: 0.7434 - precision: 0.9593 - recall: 0.9182 - val_loss: 0.0600 - val_auc: 0.9823 - val_binary_accuracy: 0.9809 - val_f1_score: 0.7436 - val_precision: 0.9362 - val_recall: 0.8094
#
# Epoch 00115: val_loss did not improve from 0.05947
# Epoch 116/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0282 - auc: 0.9981 - binary_accuracy: 0.9901 - f1_score: 0.7380 - precision: 0.9548 - recall: 0.9177 - val_loss: 0.0599 - val_auc: 0.9825 - val_binary_accuracy: 0.9810 - val_f1_score: 0.7467 - val_precision: 0.9371 - val_recall: 0.8102
#
# Epoch 00116: val_loss did not improve from 0.05947
# Epoch 117/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0244 - auc: 0.9989 - binary_accuracy: 0.9917 - f1_score: 0.7455 - precision: 0.9655 - recall: 0.9278 - val_loss: 0.0597 - val_auc: 0.9824 - val_binary_accuracy: 0.9812 - val_f1_score: 0.7446 - val_precision: 0.9370 - val_recall: 0.8127
#
# Epoch 00117: val_loss did not improve from 0.05947
# Epoch 118/125
# 78/78 [==============================] - 329s 4s/step - loss: 0.0264 - auc: 0.9984 - binary_accuracy: 0.9908 - f1_score: 0.7448 - precision: 0.9611 - recall: 0.9200 - val_loss: 0.0599 - val_auc: 0.9825 - val_binary_accuracy: 0.9811 - val_f1_score: 0.7417 - val_precision: 0.9379 - val_recall: 0.8107
#
# Epoch 00118: val_loss did not improve from 0.05947
# Epoch 119/125
# 78/78 [==============================] - 328s 4s/step - loss: 0.0252 - auc: 0.9987 - binary_accuracy: 0.9918 - f1_score: 0.7524 - precision: 0.9627 - recall: 0.9323 - val_loss: 0.0597 - val_auc: 0.9825 - val_binary_accuracy: 0.9811 - val_f1_score: 0.7432 - val_precision: 0.9364 - val_recall: 0.8122
#
# Epoch 00119: val_loss did not improve from 0.05947
# Epoch 120/125
# 62/78 [======================>.......] - ETA: 43s - loss: 0.0239 - auc: 0.9989 - binary_accuracy: 0.9919 - f1_score: 0.7354 - precision: 0.9651 - recall: 0.9293

# %% [markdown]
# ## Evaluation

# %%
#@title

def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for images, labels in dataset:
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
if Config.training.fine_tune_epochs:
  backbone.trainable = True

  frozen_layer_ix = int((1-Config.training.fine_tune_layers) * len(backbone.layers))

  for ix, l in enumerate(backbone.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not Config.training.freeze_batch_norm))

# %%
nn.load_weights(Config.experiment.fine_tune_weights.rstrip('.h5') + '-e114.h5')

# %%
l, p = labels_and_probs(nn, test)

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  ...  support        label
# 0            0.9463           0.9989  ...      205    aeroplane
# 1            0.8502           0.9985  ...      247      bicycle
# 2            0.8681           0.9985  ...      288         bird
# 3            0.8457           0.9979  ...      175         boat
# 4            0.5208           0.9938  ...      240       bottle
# 5            0.8197           0.9956  ...      183          bus
# 6            0.8127           0.9894  ...      774          car
# 7            0.8663           0.9993  ...      329          cat
# 8            0.6147           0.9788  ...      545        chair
# 9            0.8730           0.9985  ...      126          cow
# 10           0.7154           0.9927  ...      246  diningtable
# 11           0.8372           0.9967  ...      430          dog
# 12           0.9097           0.9987  ...      277        horse
# 13           0.8348           0.9985  ...      230    motorbike
# 14           0.8782           0.9733  ...     2086       person
# 15           0.5119           0.9934  ...      252  pottedplant
# 16           0.8571           0.9981  ...       98        sheep
# 17           0.6045           0.9851  ...      354         sofa
# 18           0.9498           0.9985  ...      259        train
# 19           0.7765           0.9949  ...      255    tvmonitor
#
# [20 rows x 11 columns]

# %%
co_occurrence = tf.transpose(l) @ l
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Labels Occurrence Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %%
co_occurrence = tf.transpose(p) @ p
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Occurrence Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();
